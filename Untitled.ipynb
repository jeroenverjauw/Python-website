# %%
from pathlib import Path


OUTPUT_DIR = Path("pages/PythonWidgets/CircuitGenerator")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)  # Create it if it doesn't exist
TEX_FILE = OUTPUT_DIR / "main.tex"
PDF_FILE = OUTPUT_DIR / "main.pdf"
SVG_FILE = OUTPUT_DIR / "output.svg"

def compile_latex_to_pdf(tex_file: Path, output_dir: Path):
    subprocess.run([
        "pdflatex", "-interaction=nonstopmode", "-output-format=pdf",
        f"-output-directory={output_dir.resolve()}", str(tex_file.resolve())
    ], )

compile_latex_to_pdf(TEX_FILE, OUTPUT_DIR)

# %%
compile_latex_to_pdf(TEX_FILE, OUTPUT_DIR)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[15], line 38, in compile_latex_to_pdf(tex_file, output_dir, runs, timeout)
#      37 for i in range(runs):
# ---> 38     proc = subprocess.run(
#      39         cmd_base + [tex_file.name],
#      40         stdout=subprocess.PIPE,
#      41         stderr=subprocess.STDOUT,   # merge stderr into stdout
#      42         cwd=str(cwd),
#      43         timeout=timeout,
#      44         text=True,
#      45         check=True
#      46     )
#      47     last_stdout = proc.stdout
#
# File ~\anaconda3\lib\subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     525     if check and retcode:
# --> 526         raise CalledProcessError(retcode, process.args,
#     527                                  output=stdout, stderr=stderr)
#     528 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['pdflatex', '-interaction=nonstopmode', '-file-line-error', '-output-format=pdf', '-output-directory=C:\\Users\\JeroenVerjauw\\projects\\Python website\\pages\\PythonWidgets\\CircuitGenerator', 'main.tex']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 compile_latex_to_pdf(TEX_FILE, OUTPUT_DIR)
#
# Cell In[15], line 51, in compile_latex_to_pdf(tex_file, output_dir, runs, timeout)
#      48     return last_stdout
#      49 except subprocess.CalledProcessError as e:
#      50     # Attach the pdflatex output to help debugging
# ---> 51     raise RuntimeError(
#      52         f"pdflatex failed with return code {e.returncode}.\n"
#      53         f"pdflatex output:\n{e.output}"
#      54     ) from e
#
# RuntimeError: pdflatex failed with return code 1.
# pdflatex output:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (MiKTeX 24.4) (preloaded format=pdflatex.fmt)
#  restricted \write18 enabled.
# entering extended mode
# (main.tex
# LaTeX2e <2024-11-01> patch level 1
# L3 programming layer <2024-12-25>
#
# (C:\Users\JeroenVerjauw\AppData\Local\Programs\MiKTeX\tex/latex/extsizes\extart
# icle.cls
# Document Class: extarticle 1996/10/08 v1.0 Non Standard LaTeX document class
#
# (C:\Users\JeroenVerjauw\AppData\Local\Programs\MiKTeX\tex/latex/base\size10.clo
# )
# (C:\Users\JeroenVerjauw\AppData\Local\Programs\MiKTeX\tex/latex/base\exscale.st
# y))
# (C:\Users\JeroenVerjauw\AppData\Local\Programs\MiKTeX\tex/latex/anyfontsize\any
# fontsize.sty)
# (C:\Users\JeroenVerjauw\AppData\Local\Programs\MiKTeX\tex/latex/braket\braket.s
# ty)
# (C:\Users\JeroenVerjauw\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amsmath
# .sty
# For additional information on amsmath, use the `?' option.
#
# (C:\Users\JeroenVerjauw\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amstext
# .sty
# (C:\Users\JeroenVerjauw\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amsgen.
# sty))
# (C:\Users\JeroenVerjauw\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amsbsy.
# sty)
# (C:\Users\JeroenVerjauw\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amsopn.
# sty))
# (C:\Users\JeroenVerjauw\AppData\Local\Programs\MiKTeX\tex/latex/l3backend\l3bac
# kend-pdftex.def) (main.aux)
# main.tex:8: Missing $ inserted.
# <inserted text>
#                 $
# l.8 X_
#       {\pi}
# main.tex:9: Missing $ inserted.
# <inserted text>
#                 $
# l.9 \end{document}
#
#
# [1{C:/Users/JeroenVerjauw/AppData/Local/MiKTeX/fonts/map/pdftex/pdftex.map}]
# (main.aux) )
# (see the transcript file for additional information)<C:/Users/JeroenVerjauw/App
# Data/Local/Programs/MiKTeX/fonts/type1/public/amsfonts/cm/cmmi12.pfb><C:/Users/
# JeroenVerjauw/AppData/Local/Programs/MiKTeX/fonts/type1/public/amsfonts/cm/cmr1
# 7.pfb>
# Output written on "C:\Users\JeroenVerjauw\projects\Python website\pages\PythonW
# idgets\CircuitGenerator\main.pdf" (1 page, 17868 bytes).
# Transcript written on "C:\Users\JeroenVerjauw\projects\Python website\pages\Pyt
# honWidgets\CircuitGenerator\main.log".
